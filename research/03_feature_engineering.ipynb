# %% [markdown]
# # 03 — Feature Engineering
# Build RFM, behavioural, and cohort features. Validate before porting to `features/`.

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
from pathlib import Path

sns.set_theme(style="whitegrid")
# %matplotlib inline

# %% [markdown]
# ## 2. Load cleaned data

# %%
df = pd.read_parquet("../data/interim/cleaned.parquet")
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])
print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (385081, 9)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34

# %% [markdown]
# ## 3. RFM features

# %%
snapshot_date = df["InvoiceDate"].max() + timedelta(days=1)
print(f"Snapshot date: {snapshot_date.date()}")

rfm = df.groupby("CustomerID").agg(
    Recency   = ("InvoiceDate", lambda x: (snapshot_date - x.max()).days),
    Frequency = ("InvoiceNo","nunique"),
    Monetary  = ("Revenue","sum"),
).reset_index()

rfm.describe()
# Out:
# Snapshot date: 2011-12-10
#            Recency    Frequency       Monetary
# count  4290.000000  4290.000000    4290.000000
# mean     92.574592     4.191142    1607.563469
# std      99.993918     7.465179    4815.340647
# min       1.000000     1.000000       2.900000
# 25%      18.000000     1.000000     287.962500
# 50%      51.000000     2.000000     632.060000
# 75%     143.000000     5.000000    1540.470000
# max     374.000000   205.000000  158967.800000

# %% [markdown]
# ## 4. RFM distributions

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for ax, col, color in zip(axes, ["Recency","Frequency","Monetary"], ["steelblue","coral","mediumpurple"]):
    rfm[col].clip(upper=rfm[col].quantile(0.99)).hist(bins=50, ax=ax, color=color, edgecolor="white")
    ax.set_title(col)
plt.suptitle("RFM Distributions (clipped at 99th pct)", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Log-transform skewed columns

# %%
rfm["Log_Monetary"]  = np.log1p(rfm["Monetary"])
rfm["Log_Frequency"] = np.log1p(rfm["Frequency"])

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
rfm["Log_Monetary"].hist(bins=50, ax=axes[0], color="coral", edgecolor="white")
axes[0].set_title("log1p(Monetary)")
rfm["Log_Frequency"].hist(bins=50, ax=axes[1], color="mediumpurple", edgecolor="white")
axes[1].set_title("log1p(Frequency)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Behavioural features

# %%
# Average order value + spend volatility
aov = (
    df.groupby(["CustomerID","InvoiceNo"])["Revenue"].sum()
    .reset_index()
    .groupby("CustomerID")["Revenue"]
    .agg(AOV="mean", SpendStd="std")
    .reset_index()
)

# Temporal patterns
temporal = df.groupby("CustomerID").agg(
    PreferredDayOfWeek = ("InvoiceDate", lambda x: x.dt.dayofweek.mode()[0]),
    WeekendRatio       = ("InvoiceDate", lambda x: (x.dt.dayofweek >= 5).mean()),
    PreferredHour      = ("InvoiceDate", lambda x: x.dt.hour.mode()[0]),
).reset_index()

# Product diversity
product = df.groupby("CustomerID").agg(
    UniqueSKUs     = ("StockCode", "nunique"),
    TotalItems     = ("Quantity",  "sum"),
    RepeatSKURatio = ("StockCode", lambda x: x.duplicated().mean()),
).reset_index()

# Inter-purchase gap
gaps = (
    df.groupby(["CustomerID","InvoiceNo"])["InvoiceDate"].min()
    .reset_index()
    .sort_values(["CustomerID","InvoiceDate"])
    .groupby("CustomerID")["InvoiceDate"]
    .apply(lambda x: x.diff().dt.days.dropna())
    .reset_index(level=0)
    .rename(columns={"InvoiceDate": "GapDays"})
    .groupby("CustomerID")["GapDays"]
    .agg(AvgGap="mean", StdGap="std")
    .reset_index()
)

# Return rate
returns = df.copy()
returns["IsCancelled"] = returns["InvoiceNo"].astype(str).str.startswith("C")
returns = returns.groupby("CustomerID").agg(ReturnRate=("IsCancelled","mean")).reset_index()

behavioural = (
    aov
    .merge(temporal, on="CustomerID", how="left")
    .merge(product,  on="CustomerID", how="left")
    .merge(gaps,     on="CustomerID", how="left")
    .merge(returns,  on="CustomerID", how="left")
)
print(f"Behavioural features shape: {behavioural.shape}")
behavioural.head()
# Out:
# Behavioural features shape: (4290, 12)
#   CustomerID          AOV    SpendStd  PreferredDayOfWeek  WeekendRatio  \
# 0      12347   580.057143  351.455168                   1      0.000000
# 1      12348   296.670000  225.294269                   3      0.095238
# 2      12349  1353.800000         NaN                   0      0.000000
# 3      12350   294.400000         NaN                   2      0.000000
# 4      12352   197.962857   81.916277                   1      0.000000
#
#    PreferredHour  UniqueSKUs  TotalItems  RepeatSKURatio     AvgGap  \
# 0             14         102        2218        0.436464  60.333333
# 1             19          15        1468        0.285714  94.000000
# 2              9          70         625        0.000000        NaN
# 3             16          16         196        0.000000        NaN
# 4             14          57         526        0.259740  43.000000
#
#       StdGap  ReturnRate
# 0  18.478817         0.0
# 1  70.149840         0.0
# 2        NaN         0.0
# 3        NaN         0.0
# 4  68.419296         0.0

# %% [markdown]
# ## 7. Cohort features

# %%
df["InvoiceMonth"] = df["InvoiceDate"].dt.to_period("M")

first_purchase = (
    df.groupby("CustomerID")["InvoiceMonth"]
    .min()
    .rename("CohortMonth")
    .reset_index()
)

cohort = df.merge(first_purchase, on="CustomerID")

cohort_feats = cohort.groupby("CustomerID").agg(
    CohortMonth            = ("CohortMonth",   "first"),
    ActiveMonths           = ("InvoiceMonth",  "nunique"),
    DaysSinceFirstPurchase = ("InvoiceDate",   lambda x: (x.max() - x.min()).days),
).reset_index()

cohort_feats["CohortMonth"] = cohort_feats["CohortMonth"].astype(str)
print(f"Cohort features shape: {cohort_feats.shape}")
cohort_feats.head()
# Out:
# Cohort features shape: (4290, 4)
#   CustomerID CohortMonth  ActiveMonths  DaysSinceFirstPurchase
# 0      12347     2010-12             7                     365
# 1      12348     2010-12             4                     282
# 2      12349     2011-11             1                       0
# 3      12350     2011-02             1                       0
# 4      12352     2011-02             4                     260

# %% [markdown]
# ## 8. Merge all features

# %%
features = (
    rfm
    .merge(behavioural, on="CustomerID", how="left")
    .merge(cohort_feats, on="CustomerID", how="left")
)
print(f"Final feature matrix: {features.shape}")
features.isnull().sum()[features.isnull().sum() > 0]
# Out:
# Final feature matrix: (4290, 20)
# SpendStd    1494
# AvgGap      1494
# StdGap      2322
# dtype: int64

# %% [markdown]
# ## 9. Fill remaining nulls

# %%
# StdGap is null for customers with only 1 order
features["AvgGap"] = features["AvgGap"].fillna(0)
features["StdGap"]    = features["StdGap"].fillna(0)
features["SpendStd"]  = features["SpendStd"].fillna(0)
features["ReturnRate"] = features["ReturnRate"].fillna(0)

assert features.isnull().sum().sum() == 0, "Nulls remain!"
print("No nulls remaining ✓")
# Out:
# No nulls remaining ✓

# %% [markdown]
# ## 10. Correlation heatmap

# %%
num_cols = features.select_dtypes(include=np.number).columns.tolist()
corr = features[num_cols].corr()

plt.figure(figsize=(14, 10))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap="coolwarm",
            linewidths=0.5, vmin=-1, vmax=1)
plt.title("Feature Correlation Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Save features

# %%
Path("../data/processed").mkdir(parents=True, exist_ok=True)
features.to_parquet("../data/processed/features.parquet", index=False)
print(f"Saved → data/processed/features.parquet  shape={features.shape}")
# Out:
# Saved → data/processed/features.parquet  shape=(4290, 20)

# %% [markdown]
# ## Feature Engineering Summary
#
# * Created RFM features: Recency, Frequency, and Monetary value for each customer.
# * Applied log transformations to reduce skewness in Monetary and Frequency distributions.
# * Generated behavioural features including Average Order Value (AOV), Spend Variability, Product Diversity, Purchase Timing Patterns, and Inter-Purchase Gaps.
# * Built cohort features such as Cohort Month, Active Months, and Customer Lifetime.
# * Merged all feature groups into a single customer-level feature matrix.
# * Handled missing values for customers with limited purchase history.
# * Analyzed feature relationships using a correlation heatmap.
# * Saved the final feature dataset for segmentation and predictive modeling.
#
# Result: A comprehensive customer-level feature set ready for clustering, customer segmentation, and retention analysis.
